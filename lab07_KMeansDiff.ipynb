# %% [markdown]
# # KMeans [Different Dataset]

# %% [markdown]
# ## Imports

# %%
import matplotlib
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.cluster import KMeans
import sklearn.metrics as sm
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read Data from CSV

# %%
data = pd.read_csv("heart.csv")
data.sample(10)
# Out:
#      age  sex  cp  trestbps  chol  ...  oldpeak  slope  ca  thal  heartdisease
# 52    44    1   4       112   290  ...      0.0      1   1     3             2
# 63    54    0   3       135   304  ...      0.0      1   0     3             0
# 275   64    1   1       170   227  ...      0.6      2   0     7             0
# 256   67    0   4       106   223  ...      0.3      1   2     3             0
# 149   60    0   3       102   318  ...      0.0      1   1     3             0
# 84    52    1   2       120   325  ...      0.2      1   0     3             0
# 34    44    1   3       130   233  ...      0.4      1   0     3             0
# 157   58    1   4       125   300  ...      0.0      1   2     7             1
# 79    58    1   4       150   270  ...      0.8      1   0     7             3
# 75    65    0   3       160   360  ...      0.8      1   0     3             0
#
# [10 rows x 14 columns]

# %%
X = data[['age', 'sex', 'chol', 'thalach', 'fbs', 'oldpeak']]
y = data['heartdisease']

# %% [markdown]
# ## Train

# %%
model = KMeans(n_clusters=3)
model.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# ## Results

# %%
print('The accuracy score of K-Mean: ', sm.accuracy_score(y, model.labels_))
print('The Confusion matrixof K-Mean: ', sm.confusion_matrix(y, model.labels_))
# Out:
# The accuracy score of K-Mean:  0.3696369636963696
# The Confusion matrixof K-Mean:  [[68 69 27  0  0]
#  [14 33  8  0  0]
#  [10 15 11  0  0]
#  [13 16  6  0  0]
#  [ 4  6  3  0  0]]

# %% [markdown]
# ## Analysis

# %%
plt.figure(figsize=(20, 10))
plt.subplot(1, 2, 2)
colormap = np.array(['#e74c3c', '#2ecc71', '#9b59b6', '#3498db', '#f1c40f', '#e67e22', '#34495e'])
plt.scatter(X.age, X.chol, c=colormap[model.labels_], s=40)
plt.title('K Mean Classification')
plt.xlabel('age')
plt.ylabel('chol')
# Out:
# Text(0, 0.5, 'chol')

# %%
plt.figure(figsize=(20, 10))
plt.subplot(1, 2, 2)
colormap = np.array(['#e74c3c', '#2ecc71', '#9b59b6', '#3498db', '#f1c40f', '#e67e22', '#34495e'])
plt.scatter(X.chol, X.thalach, c=colormap[model.labels_], s=40)
plt.title('K Mean Classification')
plt.xlabel('chol')
plt.ylabel('thalach')
# Out:
# Text(0, 0.5, 'thalach')
